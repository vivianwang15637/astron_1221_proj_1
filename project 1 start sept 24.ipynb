# %% [markdown]
# delete this cell later:
# Astronomy 1221 - Project 1: Python & AI Integration
# Due: Week 6 | Weight: 20% of total grade
# PROJECT OVERVIEW
# Project 1 is designed to apply Python programming skills and AI tools learned in Weeks
# 1-4 to create a practical astronomical application. Projects can range from simple data
# visualization tools using Week 1-3 material to more advanced LLM-integrated systems
# incorporating Week 4 content. The goal is to demonstrate proficiency in Python
# programming while exploring how modern AI tools can enhance astronomical
# computing workflows. We encourage people to do LLM-related projects (Week 4), but if
# you are still warming up to coding, projects without LLMs are fine—though they should
# be more elaborate using the basic tools.
# Key Philosophy: Whether you choose one of our suggested projects or design your
# own, the goal is to create robust, maintainable code that demonstrates your
# understanding of fundamental programming concepts, not just your ability to import
# solutions. Each project should result in a complete system that could actually be useful,
# not just a proof of concept.
# TEAM FORMATION & TIMELINE
# ● Teams: Work in pairs (one group of three if needed)
# ● Partner Selection: Self-assign on Carmen by Friday, Week 4, 11:59pm (09/19)
# ● Project Proposal: Submit a brief description (2-3 sentences) of your project idea
# by Friday, Week 4, 11:59pm (09/19). Feedback will be provided by Sunday 09/21
# evening.
# ● Final Report Submission: Upload completed project by Friday, Week 6,
# 11:59pm (10/03)
# ● Presentations: Week 6 during class (10 minutes per group). Time and schedule
# will be randomized with np.random.uniform()
# PROJECT REQUIREMENTS
# Technical Specifications
# ● Core Requirement: Must be Python-based and relate to astronomy (broadly
# defined). No astronomy knowledge needed—many amateur astronomer type
# questions work well.
# ● Scope: Should demonstrate mastery of concepts from Weeks 1-4
# ● Code Foundation: The bulk of the project must rely on concepts and tools we
# learned in class, but you are certainly encouraged to go beyond (not restricted to
# Page 1 of 5
# only what we taught). Significant deviation from the topics we cover will incur
# penalty up to 10 points out of the 20 points.
# Programming Standards
# All projects should demonstrate good programming practices learned in Weeks 1-4,
# including:
# ● Object-Oriented Programming: Implement at least 2-3 meaningful classes with
# multiple methods
# ● Code Organization: Well-structured functions and classes with clear purposes
# ● Error Handling: Graceful error management with try/except blocks
# ● Data Structures: Proper use of lists, dictionaries, NumPy arrays
# ● File I/O: Data persistence for meaningful applications
# ● Documentation: Clear docstrings and comments throughout
# Implementation Guidelines
# While you can use external packages for specialized tasks (particularly LLM APIs), you
# should build core functionality from scratch when possible:
# ● Implement your own word counting rather than using a text analysis library
# ● Write your own game logic rather than using a game engine
# ● Create your own data structures rather than importing specialized ones
# ● Implement your own algorithms for counting, sorting, searching, and game
# mechanics
# Note: Using NumPy, Matplotlib, and LLM APIs as taught in class is encouraged. Avoid
# importing specialized libraries that would replace core programming logic.
# Deliverables
# Single Jupyter Notebook containing:
# ● Clear markdown sections explaining your project goals and methodology
# ● Brief explanation of your class design and why you chose that structure
# ● Well-commented code cells that run sequentially without errors
# ● Results visualization and interpretation
# ● Individual contribution statement at the end
# ● Minimum Requirements: 200+ lines of meaningful code (excluding
# comments/markdown) and 1000+ words of markdown documentation
# ● Data Files: If your project uses data files, include them in the same directory
# ● Dependencies: Include !pip install or !conda install commands for any extra
# packages
# Page 2 of 5
# Note: This is deliberately open-ended so you can use your imagination, but the
# notebook must be easily readable end-to-end by your peers. Think of this as a
# publication piece you could put online for people to read.
# GitHub Bonus: While not required, we encourage uploading your project to GitHub
# (see Week 5) and adding the link to your notebook. Bonus 0.5 point for doing this.
# Presentation (10 minutes):
# ● Problem motivation (2 min)
# ● Methodology and implementation (4 min)
# ● Results and demonstration (3 min)
# ● Q&A (1 min)
# ● Slides do not need to be uploaded
# GRADING RUBRIC (20 points total)
# Notebook Quality (6 points)
# ● Clear narrative flow with markdown
# ● Code runs end-to-end without errors
# ● Proper documentation and comments
# ● Professional presentation
# Technical Implementation (6 points)
# ● Appropriate use of object-oriented programming (at least 2-3 classes)
# ● Proper use of other Python concepts from Weeks 1-4
# ● Code efficiency and organization
# ● Creative problem-solving
# ● Proper error handling
# ● Core functionality built from scratch (not just imported)
# Presentation (6 points)
# ● Clear communication
# ● Technical accuracy
# ● Time management
# ● Ability to answer questions
# Individual Contribution (2 points)
# ● Clear statement of who did what
# ● Balanced workload
# Bonus Points (up to 2 points)
# Page 3 of 5
# ● Document any LLM limitations, mistakes, or interesting failures encountered
# ● GitHub repository creation (0.5 points)
# ● Exceptional creativity or technical depth
# PROJECT SUGGESTIONS
# We provide 15 detailed project suggestions in the accompanying guidelines document,
# ranging from fact-checkers to game systems. You are absolutely free to design your
# own project as long as it meets the requirements above. If you design your own project,
# ensure it incorporates similar levels of:
# ● Object-oriented design with multiple classes
# ● LLM integration (if using Week 4 material)
# ● Data processing and manipulation
# ● Visualization with Matplotlib
# ● File I/O for persistence
# SUBMISSION GUIDELINES
# File Naming & Upload
# ● Notebook: Project1_LastName1_LastName2.ipynb
# ● Submit via Carmen under Project 1 Assignment
# ● Ensure all cells have been run and outputs are visible
# ● Maximum file size: 30MB (including data)
# Late Policy
# ● 2 points penalty per day, maximum 3 days (including weekend)
# ● Any project submitted after Monday 10/06, 11:59pm will not be accepted
# ● If presentation time doesn't work, swap with classmates and inform instructor
# ACADEMIC INTEGRITY
# ● Collaboration between teams is prohibited
# ● All external code must be properly attributed
# SUPPORT RESOURCES
# ● TA hours for project guidance, or email instructor to schedule discussion
# ● Communicate regularly with instructor and TA when unsure to ensure project
# adequacy
# TIPS FOR SUCCESS
# ● Start early - Give yourself time to iterate and improve
# Page 4 of 5
# ● Design your classes first - Think about what objects make sense for your
# project
# ● Choose wisely - Pick a project that interests both partners
# ● Keep scope reasonable - Better to do something simple well than complex
# poorly
# ● Focus on fundamentals - Demonstrate mastery of Week 1-4 concepts
# ● Document thoroughly - Use markdown cells to explain your thinking, not just
# results
# ● Build from scratch - Show your programming skills, not just your importing skills
# ● Test frequently - Ensure your notebook runs end-to-end without errors
# Remember: The best projects creatively combine fundamental tools to build something
# genuinely useful, showing deep understanding through clean, well-documented code
# that you wrote yourself. Your code should tell the story of your problem-solving process,
# not just your ability to find and import the right package. Strong use of object-oriented
# programming will demonstrate your ability to design and structure larger applications.
#
# Build a space tourism package generator that balances real constraints with
# creative marketing. The challenge is combining actual spaceflight data with appealing
# vacation packaging to create believable yet exciting experiences.
# Students gather real space data (distances, costs, travel times), use string
# formatting for professional brochures, organize destinations in dictionaries by tier,
# calculate trip logistics with NumPy arrays, and create infographic visualizations with
# Matplotlib. The LLM API generates marketing copy and itineraries. Build
# SpaceDestination and TourPackage classes, implement file I/O for destination
# databases, use try/except for impossible requests, and apply control flow for package
# customization.
# The minimal version stores 5 destinations in a dictionary, uses NumPy for basic
# distance/time calculations, generates one package description via LLM, and plots a
# simple journey map. Advanced versions might implement tiered pricing based on
# distance, use string templates for consistent branding, generate testimonials from
# different customer types, or build package comparisons with bar charts.
# Project 12: Astronomy Conference Abstract Analyzer
# make sure the project uses code we learned in class (refer to lectures 2 through 8) and can be organized well to present in a slideshow. use multiple files if needed and import things needed (like LLM API stuff).

# %% [markdown]
# Project 11: SPACE TOURISM BROCHURE GENERATOR
# Team: Rory, Vivian, Anshula
# Overview: This notebook creates vacation brochures for 5 destinations across the Universe based on estimated flight distance & time from Earth, temperature, and atmosphere. We will have a list of 30 possible stars and planets you can visit while utilizing LLM API calls to generate 3 activites with date, time, and a 2 sentence brief description. Each brocherure contains the destination name, description of destination that is stored as an attribute of the SpaceDestination class, specs (distance, travel time, etc), and a cheap and expensive version of activities as well as a cost estimate.

# %%
#setup and imports (add below)
pip install openai
from openai import OpenAI

# %% [markdown]
# # remove this cell later, i think this is an api key I made for openAI(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) but we need to use an environment to keep it secure I think?

# %%
#class design
class SpaceDestination:
    def __init__(self, name, distance, cost, description):
        self.name = name
        self.distance = distance
        self.cost = cost
        self.description = description

    def __str__(self):
        return f"{self.name}\n\nBase Cost:{self.cost}\tDistance:{self.distance}\n{self.description}"


class Activity:
    def __init__(self, name, date, time, cost, description):
        self.name = name
        self.date = date
        self.time = time
        self.cost = cost
        self.description = description

class TourPackage:
    def __init__(self, destination, tier, activity1, activity2, activity3):
        self.dest = destination
        self.tier = tier
        self.act1 = activity1
        self.act2 = activity2
        self.act3 = activity3
        
    def __str__(self):
        return (f"Activity 1: {self.act1.name}\n\nDate & Time: {self.act1.date}\t{self.act1.time}\t\tCost:{self.act1.cost}\n{self.act1.description}"
        f"\n\n\nActivity 2: {self.act2.name}\n\nDate & Time: {self.act2.date}\t{self.act2.time}\t\tCost:{self.act2.cost}\n{self.act2.description}"
        f"\n\n\nActivity 3: {self.act3.name}\n\nDate & Time: {self.act3.date}\t{self.act3.time}\t\tCost:{self.act3.cost}\n{self.act3.description}")

# %%
#database creation, 5-10 destinations with real data (add below)

# %%
#Calculations (NumPy arrays for distances/times/costs) (add below)

# %%
#Visualizations (Matplotlib) (add below)

# %%
#brochure generator (string fromatting) (add below)

# %%
#LLM integration (add below)

# %% [markdown]
# results and discussion (add below)

# %% [markdown]
# individual contribution statement (add below)

# %% [markdown]
# comments (remove this cell later)
# - where does this run so we can see the final product?
